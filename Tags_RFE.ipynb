# %%
import pandas as pd
import numpy as np
import time, warnings
import datetime as dt
import json

warnings.filterwarnings("ignore")

# %%
df = pd.read_csv('RFE_data_AVG.csv')
df = pd.DataFrame(df)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 12130 entries, 0 to 12129
# Data columns (total 10 columns):
# Unnamed: 0    12130 non-null int64
# mid           12130 non-null int64
# Recency       12130 non-null int64
# Frequency     12130 non-null int64
# Engagement    12130 non-null float64
# R_Quartile    12130 non-null int64
# F_Quartile    12130 non-null int64
# E_Quartile    12130 non-null int64
# RFEScore      12130 non-null int64
# Segment       12130 non-null object
# dtypes: float64(1), int64(8), object(1)
# memory usage: 947.7+ KB

# %%
d = pd.read_csv('analysis_member_profile.csv')
a = d.columns[1:7]
d = d.drop(a, axis=1)

# %%
d
# Out:
#            mid                       tag_1                    tag_2  \
# 0       170325                  truemove H                 truemove
# 1      3166981                        บ้าน            กฎหมายชาวบ้าน
# 2       558560                    หาเพื่อน             ชีวิตวัยรุ่น
# 3      1522673                      ซีรีส์             ซีรีส์เกาหลี
# 4      3796559              สังคมชาวพันทิป                     7 HD
# 5       498940      ชลธร คงยิ่งยง (กัปตัน)               นักแสดงชาย
# 6       682936                     นักแสดง               นักแสดงชาย
# 7       160112                         AIS               truemove H
# 8        63153                        dtac                      AIS
# 9       649373        ถ้ำหลวง ขุนน้ำนางนอน             one HD (GMM)
# 10     1599088                  ปัญหาชีวิต  การแสดงเกี่ยวกับการ์ตูน
# 11      296994                         NaN                      NaN
# 12     1074690                        บ้าน                สูตรอาหาร
# ...

# %%
d.to_csv('tags_mid.csv')
